# %% [markdown]
# https://github.com/matplotlib/mplfinance
# https://pypi.org/project/mplfinance/

# %%
# !pip install mplfinance
# Out:
# Collecting mplfinance
#   Downloading mplfinance-0.12.9b7-py3-none-any.whl (73 kB)
#      ---------------------------------------- 73.1/73.1 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in c:\users\hwuac\anaconda3\lib\site-packages (from mplfinance) (1.5.3)
# Requirement already satisfied: matplotlib in c:\users\hwuac\anaconda3\lib\site-packages (from mplfinance) (3.7.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hwuac\anaconda3\lib\site-packages (from matplotlib->mplfinance) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hwuac\anaconda3\lib\site-packages (from matplotlib->mplfinance) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hwuac\anaconda3\lib\site-packages (from matplotlib->mplfinance) (9.4.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\hwuac\anaconda3\lib\site-packages (from matplotlib->mplfinance) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hwuac\anaconda3\lib\site-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hwuac\anaconda3\lib\site-packages (from matplotlib->mplfinance) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hwuac\anaconda3\lib\site-packages (from matplotlib->mplfinance) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hwuac\anaconda3\lib\site-packages (from matplotlib->mplfinance) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\hwuac\anaconda3\lib\site-packages (from matplotlib->mplfinance) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hwuac\anaconda3\lib\site-packages (from pandas->mplfinance) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\hwuac\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)
# Installing collected packages: mplfinance
# Successfully installed mplfinance-0.12.9b7

# %%
import mplfinance as mpf
import pandas as pd

# %%
daily = pd.read_csv('mplfinance-master/examples/data/SP500_NOV2019_Hist.csv',index_col=0,parse_dates=True)
daily.index.name = 'Date'
daily.shape
daily.head(3)
daily.tail(3)
# Out:
#                Open     High      Low    Close     Volume
# Date
# 2019-11-26  3134.85  3142.69  3131.00  3140.52  986041660
# 2019-11-27  3145.49  3154.26  3143.41  3153.63  421853938
# 2019-11-29  3147.18  3150.30  3139.34  3140.98  286602291

# %%
mpf.plot(daily)

# %%
mpf.plot(daily, type ='candle')

# %%
mpf.plot(daily, type ='line')

# %%
mpf.plot(daily,type='candle',mav=(3,6,9), volume=True)
