# %%
# !pip install azure-core azure-identity certifi cffi charset-normalizer cryptography idna msal msal-extensions msgraph-core pycparser pycparser PyJWT requests six typing_extensions urllib3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.5/174.5 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.6/151.6 kB 20.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 11.8 MB/s eta 0:00:00
# ...

# %%
mailFolderid = "AQMkADAwATExAGJlNy00YzM2LWZhZmItMDACLTAwCgAuAAADz_Z31YwbCkKN_Cl-5CjHpgEAgtSmOPVKLkqtuLG1pijWrwAAAgEMAAAA"
url = "https://graph.microsoft.com/v1.0/users/hwuachen@hotmail.com/mailFolders/"
newurl = url+mailFolderid
newurl
# Out:
# 'https://graph.microsoft.com/v1.0/users/hwuachen@hotmail.com/mailFolders/AQMkADAwATExAGJlNy00YzM2LWZhZmItMDACLTAwCgAuAAADz_Z31YwbCkKN_Cl-5CjHpgEAgtSmOPVKLkqtuLG1pijWrwAAAgEMAAAA'

# %%
import requests
import configparser
import msal

# Set up API endpoint and access token
#api_endpoint = "https://graph.microsoft.com/v1.0/me/messages"
# access_token = "..."

api_endpoint = "https://graph.microsoft.com/v1.0/users/hwuachen@hotmail.com/mailFolders/AQMkADAwATExAGJlNy00YzM2LWZhZmItMDACLTAwCgAuAAADz_Z31YwbCkKN_Cl-5CjHpgEAgtSmOPVKLkqtuLG1pijWrwAAAgEMAAAA/messages"

# Set headers with access token
headers = {
    "Authorization": "Bearer " + access_token,
    "Content-Type": "application/json"
}

# Define parameters to filter emails
query_parameters = {
    "$filter": "isRead eq false"  # You can modify the filter as per your requirements
}

# Make the API request to retrieve emails
response = requests.get(api_endpoint, headers=headers, params=query_parameters)

if response.status_code == 200:
    emails = response.json().get("value", [])

    for email in emails:
        subject = email.get("subject")
        body = email.get("body").get("content")

        # Perform task identification and due date extraction logic on subject and body

        # Store the tasks and due dates in your task management system

        # Send notification or reminders if needed
else:
    print("Error retrieving emails:", response.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f8fd743b861f> in <cell line: 13>()
#      11 # Set headers with access token
#      12 headers = {
# ---> 13     "Authorization": "Bearer " + access_token,
#      14     "Content-Type": "application/json"
#      15 }
#
# NameError: name 'access_token' is not defined
